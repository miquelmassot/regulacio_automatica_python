# %%
import os
import matplotlib.pyplot as plt   # MATLAB plotting functions
from control.matlab import *  # MATLAB-like functions
# %matplotlib notebook

# %% [markdown]
# # Sistema molla - esmorteidor
#
# <img src="https://www.cs.cmu.edu/afs/cs.cmu.edu/academic/class/16311/www/s16/hw/hw3/Mass_Spring_Damper.png" />
#
# Definim un sistema molla - esmorteidor amb els següents paràmetres:
#
# <img src="https://www.cs.cmu.edu/afs/cs.cmu.edu/academic/class/16311/www/s16/hw/hw3/Mass-Spring-Damper_Equation.png"/>

# %%
# Parameters defining the system
m = 250.0           # system mass (kg)
k = 40.0            # spring constant (N/m)
b = 60.0            # damping constant (N s/m)

# %% [markdown]
# Executeu la següent cel·la per invocar l'ajuda del Jupyter Notebook

# %%
ss?

# %%
# System matrices
A = [[0, 1.], [-k/m, -b/m]]
B = [[0], [1/m]]
C = [[1., 0]]
sys = ss(A, B, C, 0)

num = [1]
den = [1, b/m, k/m]
sys2 = tf(num, den)

sys

sys2
# Out:
#          1
# -------------------
# s^2 + 0.24 s + 0.16

# %%
# Step response for the system
plt.figure(1)
yout, T = step(sys)
plt.plot(T.T, yout.T)
plt.grid()
plt.xlabel("Time (s)")
plt.ylabel("y(t) (m)")
plt.show(block=False)
# Out:
# <img src="data:image/png;base64,..." width="639.8601633300708">

# %%
# Bode plot for the system
plt.figure(2)
mag, phase, om = bode(sys, logspace(-2, 2), Plot=True)
plt.show(block=False)
# Out:
# <img src="data:image/png;base64,..." width="639.8601633300708">

# %%
# Nyquist plot for the system
plt.figure(3)
nyquist(sys, logspace(-2, 2))
plt.show(block=False)
# Out:
# <img src="data:image/png;base64,..." width="639.8601633300708">

# %%
# Root lcous plot for the system
rlocus(sys)
# Out:
# <img src="data:image/png;base64,..." width="639.8601633300708">
# (array([[-0.12 -0.38157568j, -0.12 +0.38157568j],
#         [-0.12 -0.38157568j, -0.12 +0.38157568j],
#         [-0.12 -0.38520866j, -0.12 +0.38520866j],
#         [-0.12 -0.3888077j , -0.12 +0.3888077j ],
#         [-0.12 -0.39237373j, -0.12 +0.39237373j],
#         [-0.12 -0.39590764j, -0.12 +0.39590764j],
#         [-0.12 -0.39941028j, -0.12 +0.39941028j],
#         [-0.12 -0.40288247j, -0.12 +0.40288247j],
#         [-0.12 -0.40632499j, -0.12 +0.40632499j],
#         [-0.12 -0.40973859j, -0.12 +0.40973859j],
#         [-0.12 -0.41312399j, -0.12 +0.41312399j],
#         [-0.12 -0.41648186j, -0.12 +0.41648186j],
#         [-0.12 -0.41981288j, -0.12 +0.41981288j],
#         [-0.12 -0.42311768j, -0.12 +0.42311768j],
#         [-0.12 -0.42639686j, -0.12 +0.42639686j],
#         [-0.12 -0.42965102j, -0.12 +0.42965102j],
#         [-0.12 -0.43288072j, -0.12 +0.43288072j],
# ...
